# %% [markdown]
# # RECOMMENDER SYSTEMS with SPARK

# %% [markdown]
# ## Set up Spark environment

# %% [markdown]
# ### Installation

# %%
# !apt-get update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://www-us.apache.org/dist/spark/spark-2.4.7/spark-2.4.7-bin-hadoop2.7.tgz
# !tar xf spark-2.4.7-bin-hadoop2.7.tgz
# !rm spark-2.4.7-bin-hadoop2.7.tgz
# !pip install -q findspark
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:5 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:6 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:9 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:11 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,760 kB]
# Get:12 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [900 kB]
# Ign:13 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:15 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:16 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,546 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,181 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [426 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [31.6 kB]
# Get:21 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [53.9 kB]
# Get:22 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [53.2 kB]
# Get:23 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [24.7 kB]
# Get:25 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,116 kB]
# Get:26 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [396 kB]
# Get:27 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,410 kB]
# Ign:28 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:28 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [742 kB]
# Fetched 12.9 MB in 3s (3,997 kB/s)
# Reading package lists... Done

# %% [markdown]
# ### Import from Python
# 1. Having Spark and Java installed, first we need to set relevant environment variables to use them in Colab. More specifically, you must set the locations of Java and Spark as following:

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.7-bin-hadoop2.7"

# %% [markdown]
# Note that you should do this in Python instead of Bash because we need those variables for the whole runtime. Bash commands doesn't persist as we need.

# %% [markdown]
# 2. Secondly, we can now import Spark from Python by using the `findspark` package that we installed earlier by `pip`. Next we create a Spark Session that we will use from now on:

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
spark = SparkSession.builder.master("local[*]")\
                    .config("spark.driver.memory", "16g")\
                    .getOrCreate()

# %% [markdown]
# Note: from [Spark's official document](http://spark.apache.org/docs/2.4.7/submitting-applications.html#master-urls):
# > local[*]:	Run Spark locally with as many worker threads as logical cores on your machine.
#
# Check that we successfully created a Spark Session:

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://2dba1e445fa8:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Fulfill the requirements

# %% [markdown]
# ### 1. Requirement 1

# %% [markdown]
# Study a state-of-the-art (SOTA) collaborative filtering approach and present your findings.

# %% [markdown]
# Đã trình bày ở lớp học

# %% [markdown]
# ### 2. Requirement 2

# %% [markdown]
# Implement the chosen algorithm studied above on Google Colab and Spark environment.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# import image file from drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/bigdata-rs')
# !ls
# Out:
# 'Copy of PySpark Colab - CQ17'	 spark-2.4.7-bin-hadoop2.7.tgz.1
#  ml-1m				 summary_ml1m.txt
#  spark-2.4.7-bin-hadoop2.7

# %%
import numpy as np
from time import time

import tensorflow as tf
import sys

# %%
  seed = int(time())
  np.random.seed(seed)

# %%
def loadData(path='./', valfrac=0.1, delimiter='::', seed=1234,
             transpose=False):
    '''
    loads ml-1m data

    :param path: path to the ratings file
    :param valfrac: fraction of data to use for validation
    :param delimiter: delimiter used in data file
    :param seed: random seed for validation splitting
    :param transpose: flag to transpose output matrices (swapping users with movies)
    :return: train ratings (n_u, n_m), valid ratings (n_u, n_m)
    '''
    np.random.seed(seed)

    tic = time()
    print('reading data...')
    data = np.loadtxt(path, skiprows=0, delimiter=delimiter).astype('int32')
    print('data read in', time() - tic, 'seconds')

    n_u = np.unique(data[:, 0]).shape[0]  # number of users
    n_m = np.unique(data[:, 1]).shape[0]  # number of movies
    n_r = data.shape[0]  # number of ratings

    # these dictionaries define a mapping from user/movie id to to user/movie number (contiguous from zero)
    udict = {}
    for i, u in enumerate(np.unique(data[:, 0]).tolist()):
        udict[u] = i
    mdict = {}
    for i, m in enumerate(np.unique(data[:, 1]).tolist()):
        mdict[m] = i

    # shuffle indices
    idx = np.arange(n_r)
    np.random.shuffle(idx)

    trainRatings = np.zeros((n_u, n_m), dtype='float32')
    validRatings = np.zeros((n_u, n_m), dtype='float32')

    for i in range(n_r):
        u_id = data[idx[i], 0]
        m_id = data[idx[i], 1]
        r = data[idx[i], 2]

        # the first few ratings of the shuffled data array are validation data
        if i <= valfrac * n_r:
            validRatings[udict[u_id], mdict[m_id]] = int(r)
        # the rest are training data
        else:
            trainRatings[udict[u_id], mdict[m_id]] = int(r)

    if transpose:
        trainRatings = trainRatings.T
        validRatings = validRatings.T

    print('loaded dense data matrix')

    return trainRatings, validRatings

# %%
# define network functions
def kernel(u, v):
    """
    Sparsifying kernel function

    :param u: input vectors [n_in, 1, n_dim]
    :param v: output vectors [1, n_hid, n_dim]
    :return: input to output connection matrix
    """
    dist = tf.norm(u - v, ord=2, axis=2)
    hat = tf.maximum(0., 1. - dist**2)
    return hat

# %%
def kernel_layer(x, n_hid, n_dim, activation, lambda_s,
                 lambda_2, name):
    """
    a kernel sparsified layer

    :param x: input [batch, channels]
    :param n_hid: number of hidden units
    :param n_dim: number of dimensions to embed for kernelization
    :param activation: output activation
    :param name: layer name for scoping
    :return: layer output, regularization term
    """

    # define variables
    with tf.variable_scope(name):
        W = tf.get_variable('W', [x.shape[1], n_hid])
        n_in = x.get_shape().as_list()[1]
        u = tf.get_variable('u', initializer=tf.random.truncated_normal([n_in, 1, n_dim], 0., 1e-3))
        v = tf.get_variable('v', initializer=tf.random.truncated_normal([1, n_hid, n_dim], 0., 1e-3))
        b = tf.get_variable('b', [n_hid])

    # compute sparsifying kernel
    # as u and v move further from each other for some given pair of neurons, their connection
    # decreases in strength and eventually goes to zero.
    w_hat = kernel(u, v)

    # compute regularization terms
    sparse_reg = tf.contrib.layers.l2_regularizer(lambda_s)
    sparse_reg_term = tf.contrib.layers.apply_regularization(sparse_reg, [w_hat])

    l2_reg = tf.contrib.layers.l2_regularizer(lambda_2)
    l2_reg_term = tf.contrib.layers.apply_regularization(l2_reg, [W])

    # compute output
    W_eff = W * w_hat
    y = tf.matmul(x, W_eff) + b
    y = activation(y)
    return y, sparse_reg_term + l2_reg_term

# %%
def kernelNet(dataset='ml-1m', seed=seed):

  path = './' + dataset+ '/ratings.dat'
  # load data
  tr, vr = loadData(path, delimiter='::',
                    seed=seed, transpose=True, valfrac=0.1)

  tm = np.greater(tr, 1e-12).astype('float32')  # masks indicating non-zero entries
  vm = np.greater(vr, 1e-12).astype('float32')

  n_m = tr.shape[0]  # number of movies
  n_u = tr.shape[1]  # number of users (may be switched depending on 'transpose' in loadData)

  # Set hyper-parameters
  n_hid = 500
  lambda_2 = 60.0
  lambda_s = 0.013
  n_layers = 2
  output_every = 50  # evaluate performance on test set; breaks l-bfgs loop
  n_epoch = n_layers * 10 * output_every
  verbose_bfgs = True
  use_gpu = True
  if not use_gpu:
      os.environ['CUDA_VISIBLE_DEVICES'] = ''
      
  # Input placeholders
  R = tf.placeholder("float", [None, n_u])

  # Instantiate network
  y = R
  reg_losses = None
  for i in range(n_layers):
      y, reg_loss = kernel_layer(x=y, n_hid=n_hid, n_dim=5, activation=tf.nn.sigmoid, lambda_s=lambda_s,
                  lambda_2=lambda_2, name=str(i))
      reg_losses = reg_loss if reg_losses is None else reg_losses + reg_loss
  prediction, reg_loss = kernel_layer(x=y, n_hid=n_u, n_dim=5, activation=tf.identity, lambda_s=lambda_s,
                  lambda_2=lambda_2, name='out')
  reg_losses = reg_losses + reg_loss

  # Compute loss (symbolic)
  diff = tm*(R - prediction)
  sqE = tf.nn.l2_loss(diff)
  loss = sqE + reg_losses

  # Instantiate L-BFGS Optimizer
  optimizer = tf.contrib.opt.ScipyOptimizerInterface(loss, options={'maxiter': output_every,
                                                                    'disp': verbose_bfgs,
                                                                    'maxcor': 10},
                                                    method='L-BFGS-B')


  summary_file = 'summary_' + dataset + '.txt'

  # Training and validation loop
  init = tf.global_variables_initializer()
  with tf.Session() as sess:
      sess.run(init)
      for i in range(int(n_epoch / output_every)):
          optimizer.minimize(sess, feed_dict={R: tr}) #do maxiter optimization steps
          pre = sess.run(prediction, feed_dict={R: tr}) #predict ratings

          error = (vm * (np.clip(pre, 1., 5.) - vr) ** 2).sum() / vm.sum() #compute validation error
          error_train = (tm * (np.clip(pre, 1., 5.) - tr) ** 2).sum() / tm.sum() #compute train error

          print('.-^-._' * 12)
          print('epoch:', i, 'validation rmse:', np.sqrt(error), 'train rmse:', np.sqrt(error_train))
          print('.-^-._' * 12)

      with open(summary_file, 'a') as file:
          for a in sys.argv[1:]:
              file.write(a + ' ')
          file.write(str(np.sqrt(error)) + ' ' + str(np.sqrt(error_train))
                    + ' ' + str(seed) + '\n')
          file.close()

# %% [markdown]
# ### 3. Requirement 3

# %% [markdown]
# Run your implementation on the standard benchmark MovieLens 1M movie ratings.

# %%
kernelNet(dataset='ml-1m', seed=seed)
# Out:
# reading data...
# data read in 10.036483526229858 seconds
# loaded dense data matrix
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 441513.218750
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 0 validation rmse: 0.88670534 train rmse: 0.87031895
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 379011.812500
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 1 validation rmse: 0.8562874 train rmse: 0.8145723
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 352854.562500
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 2 validation rmse: 0.8401835 train rmse: 0.78515005
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 339950.687500
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 3 validation rmse: 0.8356185 train rmse: 0.76010084
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 333031.187500
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 4 validation rmse: 0.83187276 train rmse: 0.7429739
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 327618.687500
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 5 validation rmse: 0.83150226 train rmse: 0.7285364
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 322265.937500
#   Number of iterations: 50
#   Number of functions evaluations: 55
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 6 validation rmse: 0.82921344 train rmse: 0.72343075
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 319677.562500
#   Number of iterations: 50
#   Number of functions evaluations: 55
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 7 validation rmse: 0.82838833 train rmse: 0.71742
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 317994.187500
#   Number of iterations: 50
#   Number of functions evaluations: 53
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 8 validation rmse: 0.82755303 train rmse: 0.71154803
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 316676.250000
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 9 validation rmse: 0.82679594 train rmse: 0.7061554
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 315661.843750
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 10 validation rmse: 0.8262987 train rmse: 0.7028664
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 314769.281250
#   Number of iterations: 50
#   Number of functions evaluations: 52
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 11 validation rmse: 0.8262604 train rmse: 0.6991644
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 313913.468750
#   Number of iterations: 50
#   Number of functions evaluations: 53
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 12 validation rmse: 0.82615185 train rmse: 0.6961662
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 313194.812500
#   Number of iterations: 50
#   Number of functions evaluations: 56
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 13 validation rmse: 0.8261947 train rmse: 0.6934494
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 312519.312500
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 14 validation rmse: 0.82632166 train rmse: 0.6912855
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 311903.375000
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 15 validation rmse: 0.82607067 train rmse: 0.68930227
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 311271.093750
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 16 validation rmse: 0.8264487 train rmse: 0.6877113
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 310487.500000
#   Number of iterations: 50
#   Number of functions evaluations: 53
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 17 validation rmse: 0.82686025 train rmse: 0.6854515
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 309490.468750
#   Number of iterations: 50
#   Number of functions evaluations: 55
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 18 validation rmse: 0.8267706 train rmse: 0.6840771
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# INFO:tensorflow:Optimization terminated with:
#   Message: b'STOP: TOTAL NO. of ITERATIONS REACHED LIMIT'
#   Objective function value: 308503.062500
#   Number of iterations: 50
#   Number of functions evaluations: 54
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._
# epoch: 19 validation rmse: 0.82712615 train rmse: 0.6825071
# .-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._.-^-._

# %% [markdown]
# ### 4. Requirement 4

# %% [markdown]
# #### 4.1. Implement the baseline algorithm supported by Apache Spark and another SOTA approach that is comparative to your approach

# %% [markdown]
# ##### 4.1.1. Implement the ALS algorithm by Spark

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType, Row

def dataLoaderALS(path='./ml-1m/ratings.dat', delimiter='::',
                  seed=seed, valfrac=0.1):
  schema = StructType([
        StructField("userId",IntegerType(),True),
        StructField("movieId",IntegerType(),True),
        StructField("rating",DoubleType(),True),
        StructField("timestamp", IntegerType(), True),
        ])
  rdd = spark.sparkContext.textFile(path)\
        .map(lambda x: x.split('::'))\
        .map(lambda x: [int(x[0]), int(x[1]), float(x[2]), int(x[3])])
  data = spark.createDataFrame(data=rdd, schema=schema)
  return data

# %%
path = os.getcwd() + '/ml-1m/ratings.dat'
data = dataLoaderALS(path, '::', seed, 0.1)
data = data.drop('timestamp')
data.printSchema()
# Out:
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- rating: double (nullable = true)

# %%
# split data into train and test sets with 90:10 proportions
train, test = data.randomSplit([0.9, 0.1], seed=seed)
# cache to reduce time taken
train.cache()
# Out:
# DataFrame[userId: int, movieId: int, rating: double]

# %%
# import the ALS algorithm we will be using
from pyspark.ml.recommendation import ALS

#instantiate model with the "drop" cold start strategy
model = ALS(coldStartStrategy="drop")

# %%
# set the column names for the required data
model.setItemCol("movieId")\
    .setUserCol("userId")\
    .setRatingCol("rating")
# Out:
# ALS_687af8489039

# %%
model = model.fit(train)

# %%
predictions = model.transform(test)

# %%
# import the regression evaluator
from pyspark.ml.evaluation import RegressionEvaluator

# instantiate evaluator, specifying the desired metric "mae" and the columns
# that contain the predictions and the actual values
evaluator = RegressionEvaluator(metricName="rmse", predictionCol="prediction", labelCol="rating")

# %%
# evaluate the output of our model
rmse = evaluator.evaluate(predictions)
print('The ALS RMSE is ' + str(rmse))
# Out:
# The ALS RMSE is 0.8665453923948111

# %% [markdown]
# Nhận xét: Thuật toán ALS trên Spark đã cho kết quả RMSE xấp xỉ 0.867

# %% [markdown]
# ##### 4.1.2. Implement another SOTA

# %%
# !git clone https://github.com/gtshs2/Autorec.git
# Out:
# Cloning into 'Autorec'...
# remote: Enumerating objects: 45, done.
# remote: Total 45 (delta 0), reused 0 (delta 0), pack-reused 45
# Unpacking objects: 100% (45/45), done.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# %cd Autorec/
# !python main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Testing // Epoch 333 //  Total cost = 75849.66  RMSE = 0.85465 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 334 //  Total cost = 234187.26 Elapsed time : 0 sec
# Testing // Epoch 334 //  Total cost = 76249.35  RMSE = 0.85696 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 335 //  Total cost = 233902.24 Elapsed time : 0 sec
# Testing // Epoch 335 //  Total cost = 76509.70  RMSE = 0.85850 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 336 //  Total cost = 233208.69 Elapsed time : 0 sec
# Testing // Epoch 336 //  Total cost = 76379.53  RMSE = 0.85774 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 337 //  Total cost = 233245.68 Elapsed time : 0 sec
# Testing // Epoch 337 //  Total cost = 76076.51  RMSE = 0.85600 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 338 //  Total cost = 233067.86 Elapsed time : 0 sec
# Testing // Epoch 338 //  Total cost = 75922.28  RMSE = 0.85507 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 339 //  Total cost = 233521.92 Elapsed time : 0 sec
# Testing // Epoch 339 //  Total cost = 76352.45  RMSE = 0.85759 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 340 //  Total cost = 233865.99 Elapsed time : 0 sec
# Testing // Epoch 340 //  Total cost = 76991.52  RMSE = 0.86134 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 341 //  Total cost = 234319.00 Elapsed time : 0 sec
# Testing // Epoch 341 //  Total cost = 76274.15  RMSE = 0.85712 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 342 //  Total cost = 234055.23 Elapsed time : 0 sec
# Testing // Epoch 342 //  Total cost = 76507.29  RMSE = 0.85847 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 343 //  Total cost = 233068.70 Elapsed time : 0 sec
# Testing // Epoch 343 //  Total cost = 76825.77  RMSE = 0.86037 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 344 //  Total cost = 232895.83 Elapsed time : 0 sec
# Testing // Epoch 344 //  Total cost = 76186.23  RMSE = 0.85664 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 345 //  Total cost = 232747.80 Elapsed time : 0 sec
# Testing // Epoch 345 //  Total cost = 76181.09  RMSE = 0.85662 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 346 //  Total cost = 232500.99 Elapsed time : 0 sec
# Testing // Epoch 346 //  Total cost = 76220.88  RMSE = 0.85688 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 347 //  Total cost = 232188.45 Elapsed time : 0 sec
# Testing // Epoch 347 //  Total cost = 75885.98  RMSE = 0.85492 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 348 //  Total cost = 231686.30 Elapsed time : 0 sec
# Testing // Epoch 348 //  Total cost = 76396.38  RMSE = 0.85792 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 349 //  Total cost = 231715.36 Elapsed time : 0 sec
# Testing // Epoch 349 //  Total cost = 75986.25  RMSE = 0.85551 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 350 //  Total cost = 231176.48 Elapsed time : 0 sec
# Testing // Epoch 350 //  Total cost = 76678.30  RMSE = 0.85959 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 351 //  Total cost = 230745.91 Elapsed time : 0 sec
# Testing // Epoch 351 //  Total cost = 76035.49  RMSE = 0.85584 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 352 //  Total cost = 230780.33 Elapsed time : 0 sec
# Testing // Epoch 352 //  Total cost = 76489.37  RMSE = 0.85852 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 353 //  Total cost = 231292.16 Elapsed time : 0 sec
# Testing // Epoch 353 //  Total cost = 76086.06  RMSE = 0.85614 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 354 //  Total cost = 232035.95 Elapsed time : 0 sec
# Testing // Epoch 354 //  Total cost = 76863.77  RMSE = 0.86064 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 355 //  Total cost = 232471.65 Elapsed time : 0 sec
# Testing // Epoch 355 //  Total cost = 76366.91  RMSE = 0.85776 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 356 //  Total cost = 231971.46 Elapsed time : 0 sec
# Testing // Epoch 356 //  Total cost = 76130.42  RMSE = 0.85635 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 357 //  Total cost = 231710.25 Elapsed time : 0 sec
# Testing // Epoch 357 //  Total cost = 76369.52  RMSE = 0.85774 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 358 //  Total cost = 231701.32 Elapsed time : 0 sec
# Testing // Epoch 358 //  Total cost = 76021.21  RMSE = 0.85568 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 359 //  Total cost = 232089.26 Elapsed time : 0 sec
# Testing // Epoch 359 //  Total cost = 76387.28  RMSE = 0.85786 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 360 //  Total cost = 232130.89 Elapsed time : 0 sec
# Testing // Epoch 360 //  Total cost = 76132.95  RMSE = 0.85634 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 361 //  Total cost = 231590.05 Elapsed time : 0 sec
# Testing // Epoch 361 //  Total cost = 76140.54  RMSE = 0.85643 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 362 //  Total cost = 231842.77 Elapsed time : 0 sec
# Testing // Epoch 362 //  Total cost = 76256.30  RMSE = 0.85709 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 363 //  Total cost = 232991.86 Elapsed time : 0 sec
# Testing // Epoch 363 //  Total cost = 76606.03  RMSE = 0.85911 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 364 //  Total cost = 234047.76 Elapsed time : 0 sec
# Testing // Epoch 364 //  Total cost = 76813.28  RMSE = 0.86031 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 365 //  Total cost = 232860.49 Elapsed time : 0 sec
# Testing // Epoch 365 //  Total cost = 75910.35  RMSE = 0.85502 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 366 //  Total cost = 230780.65 Elapsed time : 0 sec
# Testing // Epoch 366 //  Total cost = 75888.18  RMSE = 0.85493 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 367 //  Total cost = 230629.72 Elapsed time : 0 sec
# Testing // Epoch 367 //  Total cost = 76045.52  RMSE = 0.85588 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 368 //  Total cost = 230592.94 Elapsed time : 0 sec
# Testing // Epoch 368 //  Total cost = 76746.57  RMSE = 0.86000 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 369 //  Total cost = 231219.22 Elapsed time : 0 sec
# Testing // Epoch 369 //  Total cost = 75877.44  RMSE = 0.85492 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 370 //  Total cost = 231670.85 Elapsed time : 0 sec
# Testing // Epoch 370 //  Total cost = 76463.98  RMSE = 0.85833 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 371 //  Total cost = 231327.92 Elapsed time : 0 sec
# Testing // Epoch 371 //  Total cost = 75927.59  RMSE = 0.85520 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 372 //  Total cost = 230711.21 Elapsed time : 0 sec
# Testing // Epoch 372 //  Total cost = 76516.04  RMSE = 0.85866 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 373 //  Total cost = 230576.61 Elapsed time : 0 sec
# Testing // Epoch 373 //  Total cost = 75946.48  RMSE = 0.85532 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 374 //  Total cost = 230273.75 Elapsed time : 0 sec
# Testing // Epoch 374 //  Total cost = 75959.64  RMSE = 0.85542 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 375 //  Total cost = 231024.41 Elapsed time : 0 sec
# Testing // Epoch 375 //  Total cost = 76620.26  RMSE = 0.85927 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 376 //  Total cost = 231394.67 Elapsed time : 0 sec
# Testing // Epoch 376 //  Total cost = 76331.59  RMSE = 0.85756 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 377 //  Total cost = 231958.30 Elapsed time : 0 sec
# Testing // Epoch 377 //  Total cost = 75430.62  RMSE = 0.85223 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 378 //  Total cost = 232027.48 Elapsed time : 0 sec
# Testing // Epoch 378 //  Total cost = 76227.04  RMSE = 0.85697 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 379 //  Total cost = 232216.43 Elapsed time : 0 sec
# Testing // Epoch 379 //  Total cost = 75925.48  RMSE = 0.85513 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 380 //  Total cost = 231680.76 Elapsed time : 0 sec
# Testing // Epoch 380 //  Total cost = 75868.50  RMSE = 0.85483 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 381 //  Total cost = 231010.71 Elapsed time : 0 sec
# Testing // Epoch 381 //  Total cost = 76137.37  RMSE = 0.85639 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 382 //  Total cost = 230418.47 Elapsed time : 0 sec
# Testing // Epoch 382 //  Total cost = 76013.12  RMSE = 0.85565 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 383 //  Total cost = 230657.01 Elapsed time : 0 sec
# Testing // Epoch 383 //  Total cost = 75859.88  RMSE = 0.85484 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 384 //  Total cost = 230986.43 Elapsed time : 0 sec
# Testing // Epoch 384 //  Total cost = 76144.62  RMSE = 0.85646 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 385 //  Total cost = 230618.23 Elapsed time : 0 sec
# Testing // Epoch 385 //  Total cost = 76495.70  RMSE = 0.85854 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 386 //  Total cost = 231805.46 Elapsed time : 0 sec
# Testing // Epoch 386 //  Total cost = 75563.86  RMSE = 0.85307 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 387 //  Total cost = 231564.09 Elapsed time : 0 sec
# Testing // Epoch 387 //  Total cost = 76677.98  RMSE = 0.85961 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 388 //  Total cost = 231863.24 Elapsed time : 0 sec
# Testing // Epoch 388 //  Total cost = 76401.62  RMSE = 0.85795 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 389 //  Total cost = 231345.02 Elapsed time : 0 sec
# Testing // Epoch 389 //  Total cost = 76167.83  RMSE = 0.85661 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 390 //  Total cost = 230914.15 Elapsed time : 0 sec
# Testing // Epoch 390 //  Total cost = 76475.59  RMSE = 0.85842 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 391 //  Total cost = 231251.09 Elapsed time : 0 sec
# Testing // Epoch 391 //  Total cost = 76111.91  RMSE = 0.85629 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 392 //  Total cost = 232383.34 Elapsed time : 0 sec
# Testing // Epoch 392 //  Total cost = 76096.23  RMSE = 0.85615 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 393 //  Total cost = 232457.37 Elapsed time : 0 sec
# Testing // Epoch 393 //  Total cost = 77128.98  RMSE = 0.86219 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 394 //  Total cost = 232313.41 Elapsed time : 0 sec
# Testing // Epoch 394 //  Total cost = 76370.54  RMSE = 0.85773 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 395 //  Total cost = 230767.93 Elapsed time : 0 sec
# Testing // Epoch 395 //  Total cost = 75497.96  RMSE = 0.85264 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 396 //  Total cost = 230548.20 Elapsed time : 0 sec
# Testing // Epoch 396 //  Total cost = 76318.35  RMSE = 0.85749 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 397 //  Total cost = 230323.58 Elapsed time : 0 sec
# Testing // Epoch 397 //  Total cost = 76212.74  RMSE = 0.85690 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 398 //  Total cost = 230047.12 Elapsed time : 0 sec
# Testing // Epoch 398 //  Total cost = 75736.51  RMSE = 0.85409 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 399 //  Total cost = 230544.74 Elapsed time : 0 sec
# Testing // Epoch 399 //  Total cost = 76057.78  RMSE = 0.85598 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 400 //  Total cost = 229551.84 Elapsed time : 0 sec
# Testing // Epoch 400 //  Total cost = 76278.59  RMSE = 0.85730 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 401 //  Total cost = 229327.14 Elapsed time : 0 sec
# Testing // Epoch 401 //  Total cost = 75588.42  RMSE = 0.85324 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 402 //  Total cost = 228896.81 Elapsed time : 0 sec
# Testing // Epoch 402 //  Total cost = 75924.96  RMSE = 0.85523 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 403 //  Total cost = 229612.63 Elapsed time : 0 sec
# Testing // Epoch 403 //  Total cost = 75871.70  RMSE = 0.85495 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 404 //  Total cost = 229967.07 Elapsed time : 0 sec
# Testing // Epoch 404 //  Total cost = 76050.90  RMSE = 0.85598 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 405 //  Total cost = 229515.68 Elapsed time : 0 sec
# Testing // Epoch 405 //  Total cost = 76468.27  RMSE = 0.85843 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 406 //  Total cost = 229628.84 Elapsed time : 0 sec
# Testing // Epoch 406 //  Total cost = 75255.51  RMSE = 0.85125 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 407 //  Total cost = 230221.44 Elapsed time : 0 sec
# Testing // Epoch 407 //  Total cost = 75670.65  RMSE = 0.85374 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 408 //  Total cost = 229597.28 Elapsed time : 0 sec
# Testing // Epoch 408 //  Total cost = 75997.32  RMSE = 0.85567 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 409 //  Total cost = 229170.16 Elapsed time : 0 sec
# Testing // Epoch 409 //  Total cost = 76768.80  RMSE = 0.86018 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 410 //  Total cost = 230109.08 Elapsed time : 0 sec
# Testing // Epoch 410 //  Total cost = 75625.02  RMSE = 0.85341 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 411 //  Total cost = 229557.65 Elapsed time : 0 sec
# Testing // Epoch 411 //  Total cost = 76240.75  RMSE = 0.85710 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 412 //  Total cost = 229047.91 Elapsed time : 0 sec
# Testing // Epoch 412 //  Total cost = 76368.59  RMSE = 0.85787 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 413 //  Total cost = 229286.47 Elapsed time : 0 sec
# Testing // Epoch 413 //  Total cost = 75817.36  RMSE = 0.85462 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 414 //  Total cost = 229511.89 Elapsed time : 0 sec
# Testing // Epoch 414 //  Total cost = 75847.52  RMSE = 0.85480 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 415 //  Total cost = 228837.00 Elapsed time : 0 sec
# Testing // Epoch 415 //  Total cost = 76219.40  RMSE = 0.85697 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 416 //  Total cost = 228926.63 Elapsed time : 0 sec
# Testing // Epoch 416 //  Total cost = 75932.82  RMSE = 0.85526 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 417 //  Total cost = 229313.85 Elapsed time : 0 sec
# Testing // Epoch 417 //  Total cost = 76022.51  RMSE = 0.85582 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 418 //  Total cost = 229914.77 Elapsed time : 0 sec
# Testing // Epoch 418 //  Total cost = 75570.73  RMSE = 0.85313 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 419 //  Total cost = 229452.54 Elapsed time : 0 sec
# Testing // Epoch 419 //  Total cost = 75659.09  RMSE = 0.85368 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 420 //  Total cost = 230066.01 Elapsed time : 0 sec
# Testing // Epoch 420 //  Total cost = 76995.52  RMSE = 0.86149 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 421 //  Total cost = 230095.88 Elapsed time : 0 sec
# Testing // Epoch 421 //  Total cost = 75789.38  RMSE = 0.85440 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 422 //  Total cost = 229824.29 Elapsed time : 0 sec
# Testing // Epoch 422 //  Total cost = 77013.71  RMSE = 0.86156 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 423 //  Total cost = 231697.71 Elapsed time : 0 sec
# Testing // Epoch 423 //  Total cost = 76179.51  RMSE = 0.85669 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 424 //  Total cost = 231707.02 Elapsed time : 0 sec
# Testing // Epoch 424 //  Total cost = 75832.54  RMSE = 0.85460 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 425 //  Total cost = 231065.96 Elapsed time : 0 sec
# Testing // Epoch 425 //  Total cost = 76269.76  RMSE = 0.85721 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 426 //  Total cost = 229684.31 Elapsed time : 0 sec
# Testing // Epoch 426 //  Total cost = 76051.25  RMSE = 0.85595 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 427 //  Total cost = 229257.78 Elapsed time : 0 sec
# Testing // Epoch 427 //  Total cost = 75910.86  RMSE = 0.85517 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 428 //  Total cost = 228828.63 Elapsed time : 0 sec
# Testing // Epoch 428 //  Total cost = 76323.09  RMSE = 0.85759 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 429 //  Total cost = 228663.15 Elapsed time : 0 sec
# Testing // Epoch 429 //  Total cost = 75698.98  RMSE = 0.85394 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 430 //  Total cost = 228771.70 Elapsed time : 0 sec
# Testing // Epoch 430 //  Total cost = 75867.96  RMSE = 0.85494 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 431 //  Total cost = 228909.41 Elapsed time : 0 sec
# Testing // Epoch 431 //  Total cost = 76045.93  RMSE = 0.85598 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 432 //  Total cost = 228839.87 Elapsed time : 0 sec
# Testing // Epoch 432 //  Total cost = 76173.62  RMSE = 0.85673 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 433 //  Total cost = 229067.24 Elapsed time : 0 sec
# Testing // Epoch 433 //  Total cost = 76235.18  RMSE = 0.85707 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 434 //  Total cost = 229295.92 Elapsed time : 0 sec
# Testing // Epoch 434 //  Total cost = 76135.45  RMSE = 0.85650 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 435 //  Total cost = 229744.38 Elapsed time : 0 sec
# Testing // Epoch 435 //  Total cost = 76122.04  RMSE = 0.85642 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 436 //  Total cost = 231286.67 Elapsed time : 0 sec
# Testing // Epoch 436 //  Total cost = 76984.93  RMSE = 0.86141 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 437 //  Total cost = 232896.12 Elapsed time : 0 sec
# Testing // Epoch 437 //  Total cost = 77120.42  RMSE = 0.86218 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 438 //  Total cost = 232803.98 Elapsed time : 0 sec
# Testing // Epoch 438 //  Total cost = 76209.06  RMSE = 0.85683 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 439 //  Total cost = 230680.72 Elapsed time : 0 sec
# Testing // Epoch 439 //  Total cost = 76023.75  RMSE = 0.85578 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 440 //  Total cost = 229411.12 Elapsed time : 0 sec
# Testing // Epoch 440 //  Total cost = 75863.64  RMSE = 0.85488 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 441 //  Total cost = 229007.47 Elapsed time : 0 sec
# Testing // Epoch 441 //  Total cost = 75521.11  RMSE = 0.85287 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 442 //  Total cost = 228113.22 Elapsed time : 0 sec
# Testing // Epoch 442 //  Total cost = 75413.39  RMSE = 0.85227 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 443 //  Total cost = 227992.59 Elapsed time : 0 sec
# Testing // Epoch 443 //  Total cost = 76353.91  RMSE = 0.85779 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 444 //  Total cost = 227584.76 Elapsed time : 0 sec
# Testing // Epoch 444 //  Total cost = 75497.15  RMSE = 0.85274 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 445 //  Total cost = 228282.62 Elapsed time : 0 sec
# Testing // Epoch 445 //  Total cost = 76030.07  RMSE = 0.85589 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 446 //  Total cost = 228509.45 Elapsed time : 0 sec
# Testing // Epoch 446 //  Total cost = 75580.66  RMSE = 0.85323 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 447 //  Total cost = 229404.33 Elapsed time : 0 sec
# Testing // Epoch 447 //  Total cost = 75777.73  RMSE = 0.85439 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 448 //  Total cost = 230009.96 Elapsed time : 0 sec
# Testing // Epoch 448 //  Total cost = 75746.35  RMSE = 0.85422 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 449 //  Total cost = 229519.28 Elapsed time : 0 sec
# Testing // Epoch 449 //  Total cost = 75555.65  RMSE = 0.85305 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 450 //  Total cost = 228726.30 Elapsed time : 0 sec
# Testing // Epoch 450 //  Total cost = 75599.30  RMSE = 0.85336 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 451 //  Total cost = 227503.17 Elapsed time : 0 sec
# Testing // Epoch 451 //  Total cost = 75551.20  RMSE = 0.85311 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 452 //  Total cost = 227045.08 Elapsed time : 0 sec
# Testing // Epoch 452 //  Total cost = 75616.92  RMSE = 0.85348 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 453 //  Total cost = 226736.18 Elapsed time : 0 sec
# Testing // Epoch 453 //  Total cost = 75820.34  RMSE = 0.85472 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 454 //  Total cost = 226651.36 Elapsed time : 0 sec
# Testing // Epoch 454 //  Total cost = 75759.36  RMSE = 0.85435 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 455 //  Total cost = 226446.05 Elapsed time : 0 sec
# Testing // Epoch 455 //  Total cost = 75794.77  RMSE = 0.85455 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 456 //  Total cost = 226543.16 Elapsed time : 0 sec
# Testing // Epoch 456 //  Total cost = 75686.51  RMSE = 0.85392 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 457 //  Total cost = 227675.31 Elapsed time : 0 sec
# Testing // Epoch 457 //  Total cost = 76242.55  RMSE = 0.85719 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 458 //  Total cost = 228313.97 Elapsed time : 0 sec
# Testing // Epoch 458 //  Total cost = 75406.39  RMSE = 0.85221 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 459 //  Total cost = 228669.25 Elapsed time : 0 sec
# Testing // Epoch 459 //  Total cost = 75964.41  RMSE = 0.85551 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 460 //  Total cost = 228564.89 Elapsed time : 0 sec
# Testing // Epoch 460 //  Total cost = 75510.52  RMSE = 0.85283 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 461 //  Total cost = 228093.41 Elapsed time : 0 sec
# Testing // Epoch 461 //  Total cost = 76407.11  RMSE = 0.85812 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 462 //  Total cost = 228083.75 Elapsed time : 0 sec
# Testing // Epoch 462 //  Total cost = 76319.23  RMSE = 0.85758 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 463 //  Total cost = 228115.57 Elapsed time : 0 sec
# Testing // Epoch 463 //  Total cost = 76398.32  RMSE = 0.85807 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 464 //  Total cost = 229195.31 Elapsed time : 0 sec
# Testing // Epoch 464 //  Total cost = 76092.62  RMSE = 0.85622 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 465 //  Total cost = 228450.75 Elapsed time : 0 sec
# Testing // Epoch 465 //  Total cost = 75555.90  RMSE = 0.85308 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 466 //  Total cost = 227815.23 Elapsed time : 0 sec
# Testing // Epoch 466 //  Total cost = 75707.97  RMSE = 0.85398 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 467 //  Total cost = 228152.46 Elapsed time : 0 sec
# Testing // Epoch 467 //  Total cost = 75532.34  RMSE = 0.85297 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 468 //  Total cost = 228516.44 Elapsed time : 0 sec
# Testing // Epoch 468 //  Total cost = 76379.10  RMSE = 0.85794 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 469 //  Total cost = 228777.69 Elapsed time : 0 sec
# Testing // Epoch 469 //  Total cost = 76007.12  RMSE = 0.85573 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 470 //  Total cost = 228119.68 Elapsed time : 0 sec
# Testing // Epoch 470 //  Total cost = 76249.02  RMSE = 0.85718 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 471 //  Total cost = 227494.17 Elapsed time : 0 sec
# Testing // Epoch 471 //  Total cost = 75909.91  RMSE = 0.85521 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 472 //  Total cost = 227021.19 Elapsed time : 0 sec
# Testing // Epoch 472 //  Total cost = 75504.84  RMSE = 0.85285 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 473 //  Total cost = 226928.47 Elapsed time : 0 sec
# Testing // Epoch 473 //  Total cost = 75812.40  RMSE = 0.85468 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 474 //  Total cost = 227709.90 Elapsed time : 0 sec
# Testing // Epoch 474 //  Total cost = 75917.77  RMSE = 0.85527 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 475 //  Total cost = 227817.42 Elapsed time : 0 sec
# Testing // Epoch 475 //  Total cost = 75749.27  RMSE = 0.85427 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 476 //  Total cost = 228295.74 Elapsed time : 0 sec
# Testing // Epoch 476 //  Total cost = 76004.02  RMSE = 0.85576 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 477 //  Total cost = 228355.21 Elapsed time : 0 sec
# Testing // Epoch 477 //  Total cost = 75967.55  RMSE = 0.85555 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 478 //  Total cost = 227990.35 Elapsed time : 0 sec
# Testing // Epoch 478 //  Total cost = 76287.41  RMSE = 0.85743 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 479 //  Total cost = 228169.76 Elapsed time : 0 sec
# Testing // Epoch 479 //  Total cost = 75624.75  RMSE = 0.85352 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 480 //  Total cost = 228448.27 Elapsed time : 0 sec
# Testing // Epoch 480 //  Total cost = 76214.06  RMSE = 0.85699 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 481 //  Total cost = 228053.66 Elapsed time : 0 sec
# Testing // Epoch 481 //  Total cost = 75709.59  RMSE = 0.85402 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 482 //  Total cost = 227261.62 Elapsed time : 0 sec
# Testing // Epoch 482 //  Total cost = 75797.31  RMSE = 0.85455 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 483 //  Total cost = 227236.87 Elapsed time : 0 sec
# Testing // Epoch 483 //  Total cost = 75743.62  RMSE = 0.85424 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 484 //  Total cost = 227165.44 Elapsed time : 0 sec
# Testing // Epoch 484 //  Total cost = 75652.72  RMSE = 0.85372 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 485 //  Total cost = 226888.31 Elapsed time : 0 sec
# Testing // Epoch 485 //  Total cost = 75661.69  RMSE = 0.85375 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 486 //  Total cost = 227123.46 Elapsed time : 0 sec
# Testing // Epoch 486 //  Total cost = 75952.30  RMSE = 0.85547 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 487 //  Total cost = 227527.86 Elapsed time : 0 sec
# Testing // Epoch 487 //  Total cost = 75601.15  RMSE = 0.85343 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 488 //  Total cost = 227990.84 Elapsed time : 0 sec
# Testing // Epoch 488 //  Total cost = 75710.93  RMSE = 0.85403 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 489 //  Total cost = 227365.57 Elapsed time : 0 sec
# Testing // Epoch 489 //  Total cost = 75975.25  RMSE = 0.85562 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 490 //  Total cost = 227219.93 Elapsed time : 0 sec
# Testing // Epoch 490 //  Total cost = 75990.74  RMSE = 0.85572 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 491 //  Total cost = 227054.87 Elapsed time : 0 sec
# Testing // Epoch 491 //  Total cost = 75275.69  RMSE = 0.85148 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 492 //  Total cost = 227552.35 Elapsed time : 0 sec
# Testing // Epoch 492 //  Total cost = 75881.11  RMSE = 0.85504 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 493 //  Total cost = 227417.73 Elapsed time : 0 sec
# Testing // Epoch 493 //  Total cost = 75973.01  RMSE = 0.85560 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 494 //  Total cost = 227530.60 Elapsed time : 0 sec
# Testing // Epoch 494 //  Total cost = 75815.34  RMSE = 0.85467 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 495 //  Total cost = 227700.75 Elapsed time : 0 sec
# Testing // Epoch 495 //  Total cost = 75713.06  RMSE = 0.85408 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 496 //  Total cost = 227542.33 Elapsed time : 0 sec
# Testing // Epoch 496 //  Total cost = 75868.13  RMSE = 0.85500 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 497 //  Total cost = 226825.58 Elapsed time : 0 sec
# Testing // Epoch 497 //  Total cost = 75720.68  RMSE = 0.85411 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 498 //  Total cost = 226895.15 Elapsed time : 0 sec
# Testing // Epoch 498 //  Total cost = 75864.38  RMSE = 0.85498 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 499 //  Total cost = 227810.90 Elapsed time : 0 sec
# Testing // Epoch 499 //  Total cost = 75727.58  RMSE = 0.85416 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 500 //  Total cost = 227991.55 Elapsed time : 0 sec
# Testing // Epoch 500 //  Total cost = 76072.41  RMSE = 0.85619 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 501 //  Total cost = 227623.84 Elapsed time : 0 sec
# Testing // Epoch 501 //  Total cost = 76156.27  RMSE = 0.85665 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 502 //  Total cost = 226473.94 Elapsed time : 0 sec
# Testing // Epoch 502 //  Total cost = 75559.12  RMSE = 0.85317 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 503 //  Total cost = 225958.76 Elapsed time : 0 sec
# Testing // Epoch 503 //  Total cost = 76064.19  RMSE = 0.85616 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 504 //  Total cost = 226277.48 Elapsed time : 0 sec
# Testing // Epoch 504 //  Total cost = 76238.99  RMSE = 0.85720 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 505 //  Total cost = 227492.31 Elapsed time : 0 sec
# Testing // Epoch 505 //  Total cost = 75967.29  RMSE = 0.85557 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 506 //  Total cost = 228077.65 Elapsed time : 0 sec
# Testing // Epoch 506 //  Total cost = 75171.13  RMSE = 0.85086 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 507 //  Total cost = 228371.47 Elapsed time : 0 sec
# Testing // Epoch 507 //  Total cost = 75608.94  RMSE = 0.85343 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 508 //  Total cost = 226811.55 Elapsed time : 0 sec
# Testing // Epoch 508 //  Total cost = 75700.12  RMSE = 0.85402 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 509 //  Total cost = 225612.47 Elapsed time : 0 sec
# Testing // Epoch 509 //  Total cost = 75421.90  RMSE = 0.85240 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 510 //  Total cost = 225133.83 Elapsed time : 0 sec
# Testing // Epoch 510 //  Total cost = 75980.42  RMSE = 0.85571 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 511 //  Total cost = 225091.41 Elapsed time : 0 sec
# Testing // Epoch 511 //  Total cost = 75368.45  RMSE = 0.85212 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 512 //  Total cost = 224885.53 Elapsed time : 0 sec
# Testing // Epoch 512 //  Total cost = 75920.40  RMSE = 0.85535 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 513 //  Total cost = 224907.67 Elapsed time : 0 sec
# Testing // Epoch 513 //  Total cost = 76051.83  RMSE = 0.85612 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 514 //  Total cost = 225463.66 Elapsed time : 0 sec
# Testing // Epoch 514 //  Total cost = 75374.91  RMSE = 0.85212 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 515 //  Total cost = 225706.58 Elapsed time : 0 sec
# Testing // Epoch 515 //  Total cost = 75996.43  RMSE = 0.85580 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 516 //  Total cost = 226348.79 Elapsed time : 0 sec
# Testing // Epoch 516 //  Total cost = 75632.98  RMSE = 0.85363 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 517 //  Total cost = 226815.28 Elapsed time : 0 sec
# Testing // Epoch 517 //  Total cost = 75328.67  RMSE = 0.85184 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 518 //  Total cost = 227325.24 Elapsed time : 0 sec
# Testing // Epoch 518 //  Total cost = 75861.47  RMSE = 0.85498 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 519 //  Total cost = 226959.38 Elapsed time : 0 sec
# Testing // Epoch 519 //  Total cost = 75871.32  RMSE = 0.85500 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 520 //  Total cost = 226655.02 Elapsed time : 0 sec
# Testing // Epoch 520 //  Total cost = 75583.98  RMSE = 0.85333 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 521 //  Total cost = 226529.61 Elapsed time : 0 sec
# ...
# Training // Epoch 1938 //  Total cost = 207393.84 Elapsed time : 0 sec
# Testing // Epoch 1938 //  Total cost = 74648.51  RMSE = 0.84852 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1939 //  Total cost = 207371.24 Elapsed time : 0 sec
# Testing // Epoch 1939 //  Total cost = 74653.09  RMSE = 0.84854 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1940 //  Total cost = 207435.70 Elapsed time : 0 sec
# Testing // Epoch 1940 //  Total cost = 74698.02  RMSE = 0.84880 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1941 //  Total cost = 207437.00 Elapsed time : 0 sec
# Testing // Epoch 1941 //  Total cost = 74681.15  RMSE = 0.84871 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1942 //  Total cost = 207410.22 Elapsed time : 0 sec
# Testing // Epoch 1942 //  Total cost = 74620.95  RMSE = 0.84835 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1943 //  Total cost = 207371.94 Elapsed time : 0 sec
# Testing // Epoch 1943 //  Total cost = 74592.33  RMSE = 0.84819 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1944 //  Total cost = 207377.52 Elapsed time : 0 sec
# Testing // Epoch 1944 //  Total cost = 74683.95  RMSE = 0.84872 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1945 //  Total cost = 207325.22 Elapsed time : 0 sec
# Testing // Epoch 1945 //  Total cost = 74604.85  RMSE = 0.84824 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1946 //  Total cost = 207412.86 Elapsed time : 0 sec
# Testing // Epoch 1946 //  Total cost = 74714.85  RMSE = 0.84891 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1947 //  Total cost = 207428.62 Elapsed time : 0 sec
# Testing // Epoch 1947 //  Total cost = 74824.22  RMSE = 0.84955 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1948 //  Total cost = 207382.46 Elapsed time : 0 sec
# Testing // Epoch 1948 //  Total cost = 74649.36  RMSE = 0.84853 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1949 //  Total cost = 207322.12 Elapsed time : 0 sec
# Testing // Epoch 1949 //  Total cost = 74759.27  RMSE = 0.84916 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1950 //  Total cost = 207159.81 Elapsed time : 0 sec
# Testing // Epoch 1950 //  Total cost = 74707.80  RMSE = 0.84887 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1951 //  Total cost = 207102.89 Elapsed time : 0 sec
# Testing // Epoch 1951 //  Total cost = 74529.74  RMSE = 0.84781 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1952 //  Total cost = 207050.48 Elapsed time : 0 sec
# Testing // Epoch 1952 //  Total cost = 74606.42  RMSE = 0.84828 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1953 //  Total cost = 207113.98 Elapsed time : 0 sec
# Testing // Epoch 1953 //  Total cost = 74612.14  RMSE = 0.84831 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1954 //  Total cost = 207143.45 Elapsed time : 0 sec
# Testing // Epoch 1954 //  Total cost = 74701.21  RMSE = 0.84883 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1955 //  Total cost = 207211.88 Elapsed time : 0 sec
# Testing // Epoch 1955 //  Total cost = 74678.41  RMSE = 0.84870 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1956 //  Total cost = 207185.17 Elapsed time : 0 sec
# Testing // Epoch 1956 //  Total cost = 74598.88  RMSE = 0.84823 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1957 //  Total cost = 207100.79 Elapsed time : 0 sec
# Testing // Epoch 1957 //  Total cost = 74668.57  RMSE = 0.84864 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1958 //  Total cost = 207076.13 Elapsed time : 0 sec
# Testing // Epoch 1958 //  Total cost = 74800.34  RMSE = 0.84942 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1959 //  Total cost = 207125.05 Elapsed time : 0 sec
# Testing // Epoch 1959 //  Total cost = 74744.29  RMSE = 0.84909 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1960 //  Total cost = 207104.46 Elapsed time : 0 sec
# Testing // Epoch 1960 //  Total cost = 74688.59  RMSE = 0.84876 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1961 //  Total cost = 207166.00 Elapsed time : 0 sec
# Testing // Epoch 1961 //  Total cost = 74698.88  RMSE = 0.84882 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1962 //  Total cost = 207184.02 Elapsed time : 0 sec
# Testing // Epoch 1962 //  Total cost = 74498.95  RMSE = 0.84763 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1963 //  Total cost = 207160.28 Elapsed time : 0 sec
# Testing // Epoch 1963 //  Total cost = 74702.67  RMSE = 0.84885 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1964 //  Total cost = 207094.46 Elapsed time : 0 sec
# Testing // Epoch 1964 //  Total cost = 74438.38  RMSE = 0.84728 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1965 //  Total cost = 207056.91 Elapsed time : 0 sec
# Testing // Epoch 1965 //  Total cost = 74654.72  RMSE = 0.84856 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1966 //  Total cost = 207123.31 Elapsed time : 0 sec
# Testing // Epoch 1966 //  Total cost = 74611.91  RMSE = 0.84831 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1967 //  Total cost = 207117.70 Elapsed time : 0 sec
# Testing // Epoch 1967 //  Total cost = 74698.34  RMSE = 0.84882 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1968 //  Total cost = 207069.31 Elapsed time : 0 sec
# Testing // Epoch 1968 //  Total cost = 74702.58  RMSE = 0.84885 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1969 //  Total cost = 207088.95 Elapsed time : 0 sec
# Testing // Epoch 1969 //  Total cost = 74666.56  RMSE = 0.84863 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1970 //  Total cost = 207048.04 Elapsed time : 0 sec
# Testing // Epoch 1970 //  Total cost = 74690.80  RMSE = 0.84877 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1971 //  Total cost = 207076.52 Elapsed time : 0 sec
# Testing // Epoch 1971 //  Total cost = 74633.34  RMSE = 0.84844 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1972 //  Total cost = 207038.81 Elapsed time : 0 sec
# Testing // Epoch 1972 //  Total cost = 74705.23  RMSE = 0.84886 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1973 //  Total cost = 207030.86 Elapsed time : 0 sec
# Testing // Epoch 1973 //  Total cost = 74547.14  RMSE = 0.84792 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1974 //  Total cost = 207100.53 Elapsed time : 0 sec
# Testing // Epoch 1974 //  Total cost = 74635.20  RMSE = 0.84844 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1975 //  Total cost = 207123.63 Elapsed time : 0 sec
# Testing // Epoch 1975 //  Total cost = 74555.48  RMSE = 0.84798 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1976 //  Total cost = 207125.03 Elapsed time : 0 sec
# Testing // Epoch 1976 //  Total cost = 74683.45  RMSE = 0.84873 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1977 //  Total cost = 207110.66 Elapsed time : 0 sec
# Testing // Epoch 1977 //  Total cost = 74644.62  RMSE = 0.84850 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1978 //  Total cost = 207132.87 Elapsed time : 0 sec
# Testing // Epoch 1978 //  Total cost = 74745.61  RMSE = 0.84910 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1979 //  Total cost = 207163.07 Elapsed time : 0 sec
# Testing // Epoch 1979 //  Total cost = 74639.49  RMSE = 0.84847 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1980 //  Total cost = 207121.88 Elapsed time : 0 sec
# Testing // Epoch 1980 //  Total cost = 74677.09  RMSE = 0.84870 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1981 //  Total cost = 207120.12 Elapsed time : 0 sec
# Testing // Epoch 1981 //  Total cost = 74723.51  RMSE = 0.84897 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1982 //  Total cost = 207064.82 Elapsed time : 0 sec
# Testing // Epoch 1982 //  Total cost = 74740.82  RMSE = 0.84907 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1983 //  Total cost = 207098.48 Elapsed time : 0 sec
# Testing // Epoch 1983 //  Total cost = 74566.34  RMSE = 0.84804 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1984 //  Total cost = 207151.63 Elapsed time : 0 sec
# Testing // Epoch 1984 //  Total cost = 74641.69  RMSE = 0.84849 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1985 //  Total cost = 207078.06 Elapsed time : 0 sec
# Testing // Epoch 1985 //  Total cost = 74636.32  RMSE = 0.84845 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1986 //  Total cost = 207057.36 Elapsed time : 0 sec
# Testing // Epoch 1986 //  Total cost = 74708.62  RMSE = 0.84888 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1987 //  Total cost = 207073.14 Elapsed time : 0 sec
# Testing // Epoch 1987 //  Total cost = 74624.74  RMSE = 0.84838 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1988 //  Total cost = 207021.67 Elapsed time : 0 sec
# Testing // Epoch 1988 //  Total cost = 74670.24  RMSE = 0.84865 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1989 //  Total cost = 207066.06 Elapsed time : 0 sec
# Testing // Epoch 1989 //  Total cost = 74652.50  RMSE = 0.84854 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1990 //  Total cost = 207077.54 Elapsed time : 0 sec
# Testing // Epoch 1990 //  Total cost = 74444.45  RMSE = 0.84732 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1991 //  Total cost = 207062.07 Elapsed time : 0 sec
# Testing // Epoch 1991 //  Total cost = 74685.96  RMSE = 0.84875 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1992 //  Total cost = 207206.84 Elapsed time : 0 sec
# Testing // Epoch 1992 //  Total cost = 74755.32  RMSE = 0.84915 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1993 //  Total cost = 207075.65 Elapsed time : 0 sec
# Testing // Epoch 1993 //  Total cost = 74731.09  RMSE = 0.84901 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1994 //  Total cost = 207093.38 Elapsed time : 0 sec
# Testing // Epoch 1994 //  Total cost = 74919.70  RMSE = 0.85012 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1995 //  Total cost = 207204.83 Elapsed time : 0 sec
# Testing // Epoch 1995 //  Total cost = 74708.45  RMSE = 0.84887 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1996 //  Total cost = 207168.13 Elapsed time : 0 sec
# Testing // Epoch 1996 //  Total cost = 74535.48  RMSE = 0.84786 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1997 //  Total cost = 207124.73 Elapsed time : 0 sec
# Testing // Epoch 1997 //  Total cost = 74762.47  RMSE = 0.84920 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1998 //  Total cost = 207140.86 Elapsed time : 0 sec
# Testing // Epoch 1998 //  Total cost = 74648.93  RMSE = 0.84853 Elapsed time : 0 sec
# ====================================================================================================
# Training // Epoch 1999 //  Total cost = 207128.38 Elapsed time : 0 sec
# Testing // Epoch 1999 //  Total cost = 74700.43  RMSE = 0.84884 Elapsed time : 0 sec
# ====================================================================================================

# %% [markdown]
# Nhóm đã cài đặt thuật toán I-AutoRec và đạt kết quả RMSE xấp xỉ 0.849 ở epoch thứ 2000

# %% [markdown]
# #### 4.2. Compare performances on MovieLens 1M, using RMSE.

# %% [markdown]
# Kết quả cho thấy I-AutoRec tốt hơn ALS (RMSE 0.849 vs 0.867)

# %% [markdown]
# ### 5. Requirement 5

# %% [markdown]
# Discuss the performance of the three above approaches on another dataset, which is different from the benchmark above in term of data size (should be bigger) and/or sparsity.

# %% [markdown]
# Chọn dataset movielens 10M:  10 triệu ratings, 10,680 movies, 71,000 users, density = 0.013
# Do giới hạn của RAM nên không thể chạy các thuật toán trên với tập dataset này, nhóm thu thập kết quả RMSE từ các bài báo để so sánh hiệu năng của các thuật toán

# %% [markdown]
# Ngoài ra Spark ALS recommender là một thuật toán matrix factorization sử dụng Alternating Least Squares với Weighted-Lamda-Regularization để tối ưu (ALS-WR) nên nhóm sẽ lấy kết quả của thuật toán ALS-WR làm kết quả cho thuật toán baseline được cung cấp bởi Spark

# %% [markdown]
# | Method           | RMSE   | Result from                                                                                             |
# | ---------------- | ------ | ------------------------------------------------------------------------------------------------------- |
# | ALS-WR           | 0.7830 | Strub, F., Mary, J., and Gaudel, R. Hybrid recommender system based on autoencoders                     |
# | SparseFC         | 0.769  | Lorenz K. Muller, Julien N.P. Martel, Giacomo Indiveri. Kernelized Synaptic Weight Matrices             |
# | CF-NADE 2 layers | 0.771  | Zheng, Y., Tang, B., Ding, W., and Zhou, H. A neural autoregressive approach to collaborative filtering |

# %% [markdown]
# Nhận xét: Ta có thể thấy SparseFC cho kết quả RSME vượt trội hơn so với ALS-WR và CF-NADE trên tập dataset có cả kích thước lớn hơn cũng như mật độ dữ liệu thấp hơn movielens 1M

# %% [markdown]
# ## References
# - Cài đặt PySpark trên colab: file notebook seminar [PySpark Dataframe](https://colab.research.google.com/drive/1mlULkE3YAnWnWsXj2woGvFInmiR6mV8C?usp=sharing)
# - Source code SparseFC: https://github.com/lorenzMuller/kernelNet_MovieLens
# - Cài đặt thuật toán ALS: [Spark Collaborative Filtering document](https://spark.apache.org/docs/2.2.0/ml-collaborative-filtering.html)
# - Source code I-AutoRec: https://github.com/gtshs2/Autorec
# - Kết quả RSME của các thuật toán: [Steffen Rendle, Li Zhang, Yehuda Koren. On the Difficulty of Evaluating Baselines](https://arxiv.org/pdf/1905.01395.pdf)
